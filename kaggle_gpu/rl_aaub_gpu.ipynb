# %% [markdown]
# # RL_AAUB on Kaggle GPU
#
# Edit and save this notebook in VS Code, then run **Kaggle: Submit GPU Run**. The code executes remotely on Kaggle; outputs should be saved in `/kaggle/working`.

# %%
import platform

try:
    import torch

    print(f'Python: {platform.python_version()}')
    print(f'PyTorch: {torch.__version__}')
    print(f'CUDA available: {torch.cuda.is_available()}')
    if torch.cuda.is_available():
        print(f'GPU: {torch.cuda.get_device_name(0)}')
except ImportError:
    print('PyTorch is not available in this image.')

# %%
# Add your training code below.
# Use /kaggle/input for attached Kaggle datasets and /kaggle/working for outputs.
# Example: torch.save(model.state_dict(), '/kaggle/working/model.pt')
