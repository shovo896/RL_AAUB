# %%
import subprocess
import sys

subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow==2.16.2"])

import tensorflow as tf
print("Python:", sys.executable)
print("TensorFlow:", tf.__version__)
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.16.2 (from versions: none)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow==2.16.2
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[9], line 4
#       1 import subprocess
#       2 import sys
# ----> 4 subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow==2.16.2"])
#       6 import tensorflow as tf
#       7 print("Python:", sys.executable)
#
# File /opt/anaconda3/lib/python3.13/subprocess.py:419, in check_call(*popenargs, **kwargs)
#     417     if cmd is None:
#     418         cmd = popenargs[0]
# --> 419     raise CalledProcessError(retcode, cmd)
#     420 return 0
#
# CalledProcessError: Command '['/opt/anaconda3/bin/python', '-m', 'pip', 'install', 'tensorflow==2.16.2']' returned non-zero exit status 1.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 from tensorflow.keras import layers, models
#       4 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'tensorflow'
